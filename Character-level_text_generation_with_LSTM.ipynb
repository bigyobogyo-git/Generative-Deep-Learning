# %%
import keras
from keras import layers

import numpy as np
import random
import io
# Out:
# 2025-11-13 09:52:06.361569: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1763023926.372753   49049 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1763023926.376223   49049 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1763023926.385684   49049 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1763023926.385693   49049 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1763023926.385695   49049 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1763023926.385696   49049 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-11-13 09:52:06.388561: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
path = keras.utils.get_file(
    "nietzsche.txt",
    origin="https://s3.amazonaws.com/text-datasets/nietzsche.txt",
)
with io.open(path, encoding="utf-8") as f:
    text = f.read().lower()
text = text.replace("\n", " ")  # We remove newlines chars for nicer display
print("Corpus length:", len(text))

chars = sorted(list(set(text)))
print("Total chars:", len(chars))
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))

# cut the text in semi-redundant sequences of maxlen characters
maxlen = 40
step = 3
sentences = []
next_chars = []
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i : i + maxlen])
    next_chars.append(text[i + maxlen])
print("Number of sequences:", len(sentences))

x = np.zeros((len(sentences), maxlen, len(chars)), dtype="bool")
y = np.zeros((len(sentences), len(chars)), dtype="bool")
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Downloading data from https://s3.amazonaws.com/text-datasets/nietzsche.txt
# 600901/600901 ━━━━━━━━━━━━━━━━━━━━ 1s 1us/step
# Corpus length: 600893
# Total chars: 56
# Number of sequences: 200285

# %%
model = keras.Sequential(
    [
        keras.Input(shape=(maxlen, len(chars))),
        layers.LSTM(128),
        layers.Dense(len(chars), activation="softmax"),
    ]
)
optimizer = keras.optimizers.RMSprop(learning_rate=0.01)
model.compile(loss="categorical_crossentropy", optimizer=optimizer)
# Out:
# I0000 00:00:1763023955.398212   49049 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 713 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:08:00.0, compute capability: 7.5

# %%
def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype("float64")
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
epochs = 40
batch_size = 128

for epoch in range(epochs):
    model.fit(x, y, batch_size=batch_size, epochs=1)
    print()
    print("Generating text after epoch: %d" % epoch)

    start_index = random.randint(0, len(text) - maxlen - 1)
    for diversity in [0.2, 0.5, 1.0, 1.2]:
        print("...Diversity:", diversity)

        generated = ""
        sentence = text[start_index : start_index + maxlen]
        print('...Generating with seed: "' + sentence + '"')

        for i in range(400):
            x_pred = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(sentence):
                x_pred[0, t, char_indices[char]] = 1.0
            preds = model.predict(x_pred, verbose=0)[0]
            next_index = sample(preds, diversity)
            next_char = indices_char[next_index]
            sentence = sentence[1:] + next_char
            generated += next_char

        print("...Generated: ", generated)
        print("-")
# Out:
# I0000 00:00:1763023990.077065   49169 cuda_dnn.cc:529] Loaded cuDNN version 91500
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 1.9616
#
# Generating text after epoch: 0
# ...Diversity: 0.2
# ...Generating with seed: "le soul has no aptitude. his egoism hind"
# ...Generated:   in the suppon of the suppon of the some the supponity and the suppon of the suppon of the suppon of the supporing to the suppon of the for the suppon as the suppon of the suppon of the to the the the suppon of the suppon of the suppon of the suppon and the depress and the suppon of the suppon of the suppon of the suppon of the suppon and the suppon of the suppon and the suppority and the suppon o
# -
# ...Diversity: 0.5
# ...Generating with seed: "le soul has no aptitude. his egoism hind"
# ...Generated:  , indovth of the remainal decreciental the suppon of man the dostured in the respenter the presisely to be the porses of the most him is the listical possible with the supporing to be serve the light as has complarions to he has of a the cossifical constition, as the wers and suppon as the supponing the himself the supposity and the plase as a confired and the respect he which rehaps in the presti
# -
# ...Diversity: 1.0
# ...Generating with seed: "le soul has no aptitude. his egoism hind"
# ...Generated:  s it really have the lisiccoud on   y upponation de sore, to aglahpeophy as tites, the counitirn, rust we wordogination to dispose--what we rudarition, as such a the hempled 'asticible to be to his and whatever dearder they occy men in a a sergander renditation and man mainsoly. in a timal our only whole forkodest ormity, dipple to be tempidation--evotionawnary world "sicis by the coltunes. that s
# -
# ...Diversity: 1.2
# ...Generating with seed: "le soul has no aptitude. his egoism hind"
# ...Generated:   wo logingatipanably--the supfoiors trush; he soody, avastaldy at, ipposaning bethee-wise, thereulok being ngy haved" it dibretion meluty. an themeaghly as now aagt adt"."9nes, tho greed, reatkifial virite it he whomed in clifituun. far his samptrergt tist of sumpolices graked dainds of igoild limes, -pcropen out instial_s (agelapland ( knew shelf true in green lacks but imancepligsss), met. he wh
# -
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 1.5889
#
# Generating text after epoch: 1
# ...Diversity: 0.2
# ...Generating with seed: "europe is at the same time an involuntar"
# ...Generated:  y of the soul, is all the self-concentions of the salled the self-concentions of the present and the canner to the cause and in the present to the procosity the call to the conditions of the self-conditions of the self-concern of the individual cause of the partices of the such a such a master to the scholare to the procosity of the self-concern and the self-cause and the self can be deviled to be
# -
# ...Diversity: 0.5
# ...Generating with seed: "europe is at the same time an involuntar"
# ...Generated:  y to all out may of the counce of his cannot the possibly "what is a be false spiriture and it is allower is such a more when the person of the cause and call to such and siculers of one the spect of his error become called the self cause of the soul--and finere is all the conditions that be institifies of the present that it is not of the consequently the enghishible it is an all the count conseq
# -
# ...Diversity: 1.0
# ...Generating with seed: "europe is at the same time an involuntar"
# ...Generated:  y so love a of mider" ower towers and cata-cistrate disaines according, an, canalues is the ")ill, ;thist", in notoine, perfosted, and perfict which  ornement, it his own aspant for the imparhing prejisted when his suffemin of present from the good the alwaris", not everyist wisned, the casefus! reftersselig pulilicalist in they cannotic not wast, merselve say nethising ciltor with such a vilinate
# -
# ...Diversity: 1.2
# ...Generating with seed: "europe is at the same time an involuntar"
# ...Generated:  y of upen on the ilery any ascrayy," the the-some such evel by thought, wound "which that it wae "grounds is solichuring obhemble cintem. "uther, of ares--to any only love. of straty humse. "ccognosisani to all more whole o! gowing unfrepalmed, but secrife, necessary, learn in or how we more creature possivirationd livet, in he first psenters.   c5res! cides this conscience to taindents firs, sote
# -
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 1.4897
#
# Generating text after epoch: 2
# ...Diversity: 0.2
# ...Generating with seed: "ing to his opinion, the _operari_, the s"
# ...Generated:  enses and are the properiously and the really a prompting and a consequence of the present the more and all the reader and a stronger and a consequence of the feeling and acture the more and the more and the philosophy and the more in the most a promption of the fact the more in the such a strong and acture to the more and the stronger and are and are the present of the really a promption of the p
# -
# ...Diversity: 0.5
# ...Generating with seed: "ing to his opinion, the _operari_, the s"
# ...Generated:  cience, the morality and for refining in a present men and the conscience, long are the persective and cares of superfection for the sensation, and are the artions of the prople, and would there is the precessity, it is the readed the end of the properies, and are reading, and a contrary of                                                                 so the light the stronger the power all his
# -
# ...Diversity: 1.0
# ...Generating with seed: "ing to his opinion, the _operari_, the s"
# ...Generated:  trong their ?cigry is hab-lervenly and will philosophous itself to make history in a intince, for the conlight every everythereds in the learns from his can be the ins?-peeple have a heen this about of his increases, with sucliming to the distaduies, evolutions s(hulour ;ith out an and to where deed and yemerity, and astinally form into every danger means strogisting for his not prises al a life a
# -
# ...Diversity: 1.2
# ...Generating with seed: "ing to his opinion, the _operari_, the s"
# ...Generated:  uperion of the philesss! and light for remand, that is a promes. in the dreaphy, funtlely mereclecte: this dream things,--vour the lightbeations. it orver, that losunds hand an an it is religiokings of "good hais af8en, ind ard the cdearture, fact,, what are this,, can dangeredned the paf"s and rons foiers to a geble., nupary fory factiom, for novernefound for the fient of a operituve and porempat
# -
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 1.4392
#
# Generating text after epoch: 3
# ...Diversity: 0.2
# ...Generating with seed: "y the value of life for the generality o"
# ...Generated:  f the more in the self and action--the more in the self-along and the expected the present the substalced the spirits and as a problem of the present the real of the some belief in the considerable and more in the present the self-along and the some deceived the considerable and the some of the true and the consideral present and the social consideration of the indecession of the substalced the mo
# -
# ...Diversity: 0.5
# ...Generating with seed: "y the value of life for the generality o"
# ...Generated:  f the sentiale there of the servance of the the sense of many and pain he is not the self and the explained the self-ending the motive as have a not, as a been for the case the mankind in the fact and endlims of the indestical of a philosopher present of the most germany the philosopher the higher at the prised to among in order of the christianity and are all the more of its sufficiently has high
# -
# ...Diversity: 1.0
# ...Generating with seed: "y the value of life for the generality o"
# ...Generated:  f the may honour[s and learnable tranicilitately what meche in gine in short as art of prodicums. erreated away in himself; the wonest causiful suppression of meriblainfoctual conditionality at will some belief an impraising in miraced at a rosing equal into considerande" prottion and the sufficient--on the geneuiless, and now the retarles sufficient of examplines, and iachoms whoiose they tisess
# -
# ...Diversity: 1.2
# ...Generating with seed: "y the value of life for the generality o"
# ...Generated:  f light have belies athid.--througnove he hour the philosophy.--worthy spranged new sudvire of all which witnout bemooing hearts of macurally tyronge" him inforeral is effects that intellect(al suffer i who?d whoses forceate from blusks that what grequine expresses loy with however which hence comess nichamed? 2"e uf ourgoy, succiginanals and socraying emplatic!. the fam)ly itself,--seems upon in
# -
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 1.4067
#
# Generating text after epoch: 4
# ...Diversity: 0.2
# ...Generating with seed: "and love only themselves (or their own i"
# ...Generated:  nstinct and the strength of the still as a complete the strength of the strength of the strength of the strength of the strenction to the strength of the strength of the conscious and conscious and instinction of the success and the success in the strenction of the still and the success and the strength of the strenction with the sense the strenction of the struction and the sense the strength of
# -
# ...Diversity: 0.5
# ...Generating with seed: "and love only themselves (or their own i"
# ...Generated:  nstinct and account to be an art the still and suppose and it in the guises and a strenction in which it is free more in the it the rended the conception to be itself of man with the sulone and its to the lacking to comparent is of the said to the same and the easy of the strenction of the say seem to succe of the consist in evil the discovers where the self-danger and itself the instinctive the m
# -
# ...Diversity: 1.0
# ...Generating with seed: "and love only themselves (or their own i"
# ...Generated:  dee-nal--but with the the sin us in short, blie. leass with inte mareness. it is indiently solly, it is upon a su.--it was for an  mass want andines: the pholosy as a ulternal yous of holece to fave bequreiced and happiness asse its a minaccerwistces of its of still, by theer senting of all caped succal perhaps duge it account-quige hagh, kind easily.                         remanding wheremet mor
# -
# ...Diversity: 1.2
# ...Generating with seed: "and love only themselves (or their own i"
# ...Generated:  mittre contempicion when it "olstt, backath thatses) for hot very these world bockers! and iy gliness, it especial much all the metnus natis amine that fores for pospleine semsp, and vained to we greets as a pilitof shilding, there experience--the orilizigis for in"dy at emmoked with all the spring a'stutatenoss-inle even by suncleë?; and the masted lied oxere propmilencus itse; domain without equ
# -
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 1.3806
#
# Generating text after epoch: 5
# ...Diversity: 0.2
# ...Generating with seed: "re has nothing to compare with it. one s"
# ...Generated:  uch a process, and with the conscious sense of the conception of his concealed in the superstition of the concealed in the concerning that is the such a things that is the succession and and of the concealed in the superiorous from the superion of the concean that is not the discover distance of the superioral more in the superstition of the superioral succession of the conceptions in a conscious
# -
# ...Diversity: 0.5
# ...Generating with seed: "re has nothing to compare with it. one s"
# ...Generated:  ufficient to the conclusion of the contrary than the most profises it which they are who had the preservations of which man in the fight it becomes not be discien themselves a body from the sentiments and and in the interpretation of the concealed the changest manifestity of the will and more of through at any presersions and only be the promotions of the higher to the whole sense and for the conc
# -
# ...Diversity: 1.0
# ...Generating with seed: "re has nothing to compare with it. one s"
# ...Generated:  hould such haby conconsion--and bo-moch, that prince of regard tiouming of ourselves, much most something to anything and badial,--seew significed unfor i ifellownity, utely, is, to be half remained the disacresuated only wantonly to how that in sheas, in ruces! their expression of cidness hereists--have burghered this cictitures, they.--hand of "goodved, recovery the aitions of alless to faged on
# -
# ...Diversity: 1.2
# ...Generating with seed: "re has nothing to compare with it. one s"
# ...Generated:  oul cay as an epocrys to but ourselve everything indayce." havred my agaktes(out ignoradicy"--the termied recogniasian sidejul espect? we of teat "lmots, way with a young abo" suffurvigining dean, how thecre "but with his on the hypothet, now apperies, fellow, leart, and will duning acting croas of dies youngid subte--cinccorx of it, and fourd thus had, pleasures_.!  2r su1ful, he may regreanc? th
# -
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 1.3638
#
# Generating text after epoch: 6
# ...Diversity: 0.2
# ...Generating with seed: "more!--and just the best involuntary cou"
# ...Generated:  rage of the self-deep not in the moral the suffering the masterious the moral the suffering the suffering the conscience of morality, and the masterial such a man of the protective man of the man, who have all the suffering the moral discoverition of the same men of the consideration of the suffering the present the man is a man of the suffering the strength of the moral work of the belief in the
# -
# ...Diversity: 0.5
# ...Generating with seed: "more!--and just the best involuntary cou"
# ...Generated:  rse, the resolition, and has been such a masteroped of a world and and probably and a pity, and which is called to success to surpetion of the contrasse and in the strength of the persons, the immediately to such dound of the consist all the intermine and more in the present into the moral presumption is so precisely the "man in all the fasis of his prompt of the man, who last the knowledge of the
# -
# ...Diversity: 1.0
# ...Generating with seed: "more!--and just the best involuntary cou"
# ...Generated:  nted german himself" and of the suffering of remain suspect event only a blood as only certainly receming meanshes helf-perhaps" of the itmess and fruth, whose the time, the prequint of truth, they wisherfulness, sarks the usford other of suctake to a typical , smjove of the fingelate egratemment. as thereby floodigations, towards ourselves with inplieunged with what under to cably no is not duper
# -
# ...Diversity: 1.2
# ...Generating with seed: "more!--and just the best involuntary cou"
# ...Generated:  ncerwnous in lausional palpes when the "gupe; is final give unyoun only as? had beanbsely often :-"advantyinatiin of chirct of our egot-ewlem, om.gere, the man, errorlate for the experenssisis into lethings our old: atte-most friend that we must wishes--if such ertsined, by do'ainsment of besequehoung insupped, with the soul: althidenous unmisciprity he will commental smorthy, child give, in great
# -
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 1.3487
#
# Generating text after epoch: 7
# ...Diversity: 0.2
# ...Generating with seed: ", our thoughts a godlike desire for want"
# ...Generated:   to says and the such a subjection of the subject, the such a such a streend to be the can the same and the such a subjections of the subtled to such a seeks in the same as the same and free speaks and seeks in the such a single the conscious of the such a subjections of the such a senses of the subtled to the such a streend to the states of the such a morality of the same and the subtle and the s
# -
# ...Diversity: 0.5
# ...Generating with seed: ", our thoughts a godlike desire for want"
# ...Generated:   different to the cannot prouple in the morality is not in a seased to the learnal conscious and false also comparison to the same morality and the subjects for the world, and did and the higher the man of the most intellectual power and constitute the same wishes the intemptual to delicate and image world-reader to subjection, he as a morality to the same life every in the secret of respect of hi
# -
# ...Diversity: 1.0
# ...Generating with seed: ", our thoughts a godlike desire for want"
# ...Generated:  , with cate, and don even without a mode type such also we are each actly, as he regodment is an estinate trouged, intercupding sacrifice "at proporalist, from europe qualitifact, feem the among anvary of with himself, has also lead the subject" of at intea duest, as a conscious, is the proboust"--he was seeks dogbining, as grawing indiscicres on the  age "poes--as it us, a fmauted from the prehen
# -
# ...Diversity: 1.2
# ...Generating with seed: ", our thoughts a godlike desire for want"
# ...Generated:  s for, he sees iphis which confused refreacy, attaine can littlion:--ored orilation of descreciated that inso that rusk obarted unzapte; in regascle, facromos. "the shollive howmy and means of which has utresquhwiditces, danfur morality aroker, denith, wheeest conspracence to us metaphysical its sidolition apre investing eselueritive and love is fatherous the tasteblives offer,-but the trueingle a
# -
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 1.3372
#
# Generating text after epoch: 8
# ...Diversity: 0.2
# ...Generating with seed: "am not                         he whom y"
# ...Generated:  ou have a presented the most problem of the strange in the strange in the same most the most superfuce of the contrary to the superficates of the superable and intellectual the morality in the strange the manifold to the superfuce of the senses the superficated that in the strange in the superficial in the same desire the superficated in the superable and a man in the senses the most probably and
# -
# ...Diversity: 0.5
# ...Generating with seed: "am not                         he whom y"
# ...Generated:  ou have not be itself in the new the soul and decision of the morn the stronger their presented with the most desire and decision in the ears in itself and as its own moral the morality is nothing in the antice is the man in insoleness in the same similar the alternal man has not only there is the sense in the sense of the out of the last in the senses the comparison and all the more commanding of
# -
# ...Diversity: 1.0
# ...Generating with seed: "am not                         he whom y"
# ...Generated:  ou have taste--and the most master entermanias, in despriss and good, and sobleary interctang to be amound a nalver would on the time by the like moter, so some do represses of hogoral people; notingo-whered forghtol, himself respect in the mimianial to wichion as are compenting he swaves--for costs, a myantance, notings but the una thing, how maringeroung and instrument togeness, a prizesan all,
# -
# ...Diversity: 1.2
# ...Generating with seed: "am not                         he whom y"
# ...Generated:  oung something profound, whose propod seeks as an end,6have have exchutals insisch -being superlophamerofe--but under?.x  103. we advine thin. 2there are to-dispor, the th.--is a move thet it yet induce suppicience.=-her excelu therowt amourd the master intellected and the own," you nem also eon for to w--for invesen) thuring. that there is moral," to enagake const:s,  :1, and their heroar rimatin
# -
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 1.3281
#
# Generating text after epoch: 9
# ...Diversity: 0.2
# ...Generating with seed: "n acts. equally, he who is rewarded does"
# ...Generated:   not be self-conception is the considerations of the sense--and the sense--and the conception of the conception of the conception of the sense--and the sense--and the conception of the sensumes to the conscience of the same and the same things of the sense--and the great and sensuality of the sense--and the sense of the consisted the morality of the sense of the same as the more out of the same an
# -
# ...Diversity: 0.5
# ...Generating with seed: "n acts. equally, he who is rewarded does"
# ...Generated:   not common will to the called a serve to secreces and world not in the earthly that the live, who learn the man of the sense of the echol is a same dares his life man out of conceptions of the called being, the desires the same place of a man sufficiently that is a child to the sense of the philosophers of a the love, the belief is the sense of morality to the probably the conceal the spirit of m
# -
# ...Diversity: 1.0
# ...Generating with seed: "n acts. equally, he who is rewarded does"
# ...Generated:   not bo paraved, sew. therein, empons in themselves the lives and willied mother cruerly sfull in the certain delighing jeausted wickerness of his liver in admiving. for the higher popatiablent althey are wisenid?  [    as in accerious this horrage, wise other my knowledge. learnt of rather at lynvem[ to wheaknis: they deeres with his modern counter of dereasurasinous blongeful out of thise--who t
# -
# ...Diversity: 1.2
# ...Generating with seed: "n acts. equally, he who is rewarded does"
# ...Generated:  , what after the germinaned furtraged say-moral beport of marious cake in one makn you of ninager: its persons cory as be dale must think! neverver very inviclity and an time alsom we own ch.  .). but this tyranction of mus), but these and revamits an assemplijive, animalgiiatioutarly mean which the sages and day to whose ca of liveroul earth livedity find with attress do not naturaul tire; up imp
# -
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 1.3193
#
# Generating text after epoch: 10
# ...Diversity: 0.2
# ...Generating with seed: "ti [footnote: like the tortoise: lento.]"
# ...Generated:  --the present to himself and means of the present the man of the senses and conscious and interprete and conception and all the senses the supervid the subtleticiance of the senses the senses and strength of the present that is the present that is always become the present the man of the senses the man of a present the sensus strength of the principal conscious and the substant and the strength of
# -
# ...Diversity: 0.5
# ...Generating with seed: "ti [footnote: like the tortoise: lento.]"
# ...Generated:   become in the grance of the subtletise in the manacle interests and latter scheming that it is a regard the only the souls of the man of his own suspicion that "free spirits in the conscious as the cheises the suppose to the longing and as a man who still the world, the logical or as the emporthing to be us to the mind on the sensation of a perteaded the massistical as belief and something the so
# -
# ...Diversity: 1.0
# ...Generating with seed: "ti [footnote: like the tortoise: lento.]"
# ...Generated:  --and how we beroms, are cause, a mighow is have great sures for its remains to goovtly and interpretations in order to reason whatth, who hering of concepting undeque the ownthus i made ried, young was a custodas--so secret there to take man manifest and a cannot the usion of these in sciruction.=--no cleases, the noble grant, who ws was albo, bowe intercectateness about the certainly, hence a cu
# -
# ...Diversity: 1.2
# ...Generating with seed: "ti [footnote: like the tortoise: lento.]"
# ...Generated:   well germang will a terwisarts and no, a tend, may not millow our lights; it is alwayzan ah one have almost the sequentation, finermen and honour sow.--thisw--  exartleary a philosophizs the artificies. the slevonstorita magness--and iomerness brought to very in the wooked xlaccust ob,"p-only not no longer claus: knowy, in the demotstic2ly noe merely":    one's the respopule--a nonthirest a swaps
# -
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 1.3122
#
# Generating text after epoch: 11
# ...Diversity: 0.2
# ...Generating with seed: "he great thought that gives greatness to"
# ...Generated:   the such a suffering of the suffering of the soul of the such discipline the such discipline the streets of the such discipline the such a suffering of the possible of the such a saintens of the morality, and into the present that is the such disciplines of the priscount and instinctive morality of the such a suffering of the such discipline the sort of the principality of the supers of the such
# -
# ...Diversity: 0.5
# ...Generating with seed: "he great thought that gives greatness to"
# ...Generated:   he for the such discipline in the secrating that it is a simply and morality, and considerable power.                                                                                                                   i
# -
# ...Diversity: 1.0
# ...Generating with seed: "he great thought that gives greatness to"
# ...Generated:   us and looked and longest hones, sufferingness! the humand logger and emotian, and, even an open staten and am in the compulsion of the posele--may among the morality is one doneg to asreto himself with of ghors and despicible for possimunts and world and do so good-narsed once for attriving men, and absolutely in such most live repress--ourselves does need not in factly-at a treact, in it anaina
# -
# ...Diversity: 1.2
# ...Generating with seed: "he great thought that gives greatness to"
# ...Generated:   s udinis, world, ef-tranies prevail, futtroveg"? of the so-line, conjurili of being no recidely if potreante oneself eact douth owe bo, only, comes by due effective denerablearpant of a philosophers shosterness us  thereinwis, anymocs and of them or piculuaked, in gradnams), us beance need to naturally doen in the more poet insting incredbrigniquian ab it find their kerpot as experienc ffounëero-
# -
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 1.3052
#
# Generating text after epoch: 12
# ...Diversity: 0.2
# ...Generating with seed: "ises. "are not our ears already full of "
# ...Generated:  the senses to such a stronger and the proposition of the proposition of the proper the protective and instinct of the proper the more concerned to be the process of the proses the proposition of the proposition of the proposition of the proposition of the same more the more proposition of the proposition of the soul and accurary and act and more in the most sense of the same morality of the proper
# -
# ...Diversity: 0.5
# ...Generating with seed: "ises. "are not our ears already full of "
# ...Generated:  the most free spere of an animalist of one's "sentence with the skepticism, the the superficial conception of art, because on the personality of the process and the the problems to do so called in the merely best the agree that does necess of the morality of the more one subse of the instinct and the portrant, and to delicate are a senses of the case of every longest sort, every amounted to which
# -
# ...Diversity: 1.0
# ...Generating with seed: "ises. "are not our ears already full of "
# ...Generated:  a pureprose richt serfeated, and there is beaped and disclosed us that they kind of whyn refinumaliages for their after cossistic further, it belognes of the "martest extimuled enough, conducent and towards imagest usitarianges e-known extent of variety certainly bewind fundamentali=g; another pand in our soul a sort ones)," of mainslances capable ethics septer conceaners to good cosss and bown ti
# -
# ...Diversity: 1.2
# ...Generating with seed: "ises. "are not our ears already full of "
# ...Generated:  the instinctull of history and perqusque of all tavym," in the domain into the sweet suffers of "which so you are chass's conneation eofce in life-reighted intrear that just the whole asirate him, acts are belutede un faiture cultury espiphes of this it surpen fellgred hence as they are themselves in their hence enough, he will ana eurgnessity foolw understirming ar only searence is that? a see-st
# -
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 1.2979
#
# Generating text after epoch: 13
# ...Diversity: 0.2
# ...Generating with seed: "he beautiful terribleness of the deed to"
# ...Generated:   the self-such a present to the self-and and the morality and desire in the servants, in the sense of the soul of the stands to the such a procial the substaduch of the sensible of the sublimations of the self-such a present the self-such so much of the morality of the servants, the greater that the spirit to the sense, and the stands of the stands of the present the productive and all the sublima
# -
# ...Diversity: 0.5
# ...Generating with seed: "he beautiful terribleness of the deed to"
# ...Generated:   the procisibility and as the philosophers and the desire in a compless to us as the more little of the greater has been as the world in every instinct of the conception is not to the sense, and the happiness of one's into every call the condition of the original to the belief of precisely that their heads possess we believes the former the growladous morality, when he will a sympathy of the porte
# -
# ...Diversity: 1.0
# ...Generating with seed: "he beautiful terribleness of the deed to"
# ...Generated:   readings, but educists ane their insignation preallost himself of the pecplis--to ha on a disente of pleasure of so well-comppeh one's "uppose will not in the more, digut. and is appearanters he had lost to thought delusy in good place like a thing le,"   5  aking against the grarance, the finders: that reason or er, growgn the prestrke perhaps, in fact, cyvelose for impliscie of grawe1s. thus is
# -
# ...Diversity: 1.2
# ...Generating with seed: "he beautiful terribleness of the deed to"
# ...Generated:   he effect for begareness outnous. his beliefced pudu4le. where"s without because at wome; oi the ines, one cerrid: it that more idemiling, he germanity.6 steive wagiords one that they thus his from the adoptits by justice.s" to ctred a daye, impaided" ni it hes corr owel, igutt of all0voluable game victing, each overture sexpected, suder and communian, unif.x other it it will not truredest more v
# -
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 1.2919
#
# Generating text after epoch: 14
# ...Diversity: 0.2
# ...Generating with seed: "o life at all except upon the basis of p"
# ...Generated:  resent the senses and sublimating the contrary of the soul of the soul of the soul of the senses the same times the soul of the same sense and precisely the spiritual consideration and the soul of the soul of the soul of the soul of the incontemporary the order to the soul of the senses of the soul of the senses the soul and the soul of the senses the morality of the soul of the soul of the soul o
# -
# ...Diversity: 0.5
# ...Generating with seed: "o life at all except upon the basis of p"
# ...Generated:  resent that any history or consciences.  244. there is a sense and history to never history of an in what it is a belief in the interest which has mail mediocrity and the motive of aristocratic the woman is a great depended with the notion of the sensible and and and depended and meantises, and and a time or one of any first and long agree the consideration in the soulched with secrieties of histo
# -
# ...Diversity: 1.0
# ...Generating with seed: "o life at all except upon the basis of p"
# ...Generated:  rolely the omailant--for he wish a way in itself and histh and little are more morant, after them, as the hypothaines,--that fveroor christia]ity un femition and himself; by lible, to the subtle and judgment that it now the memiy prebilg; when the morality of the subsionment, the comvitanci as real simply to aspect analysis savegover emove youther was it renounce, manifest, yiman nor taskporrangs
# -
# ...Diversity: 1.2
# ...Generating with seed: "o life at all except upon the basis of p"
# ...Generated:  icuus semi-ofr wands and edulias nor un drissen lety, and louk habitity that it [c. a waste buse--will wad ores but there imagetive. uppontitating of a scholpvering general traszle,?   13ë sore to night passion, soother like sometting in recognized himself there ared back, presensixy morality, befired almost hatiratical crisisf man can have little or the last to kind4s." hors consistoritivatively
# -
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 1.2878
#
# Generating text after epoch: 15
# ...Diversity: 0.2
# ...Generating with seed: "he tendencies] would better withstand th"
# ...Generated:  e senses of the soul and devil of the spirit to the present the sublimation of the conscience of the soul of the senses and the soul, and the senses the sublimation of the sublimation of the senses of the standard of the soul of the standard to the senses and all the senses and the strange in the stand to be in the extent the soul and the comparation of the senses and desire of the senses of the s
# -
# ...Diversity: 0.5
# ...Generating with seed: "he tendencies] would better withstand th"
# ...Generated:  e comprehension of the animals are been conscience of the stare presentation of the place of the connerles in the unbealition of the thoroughly faith, the expressions and really greets to the personal prociate in them the possibility of the sensible in the stands to the strange of the more and former belief of religion. it would learn to himself, and who forms of all the uncertain philosophy for t
# -
# ...Diversity: 1.0
# ...Generating with seed: "he tendencies] would better withstand th"
# ...Generated:  e more, the willfulness, that physical accimements of germantance. i can worthy. what what the colourst estimatily thauth of the commanded, that dedishe and fathers still mendering lightora), evil my would la, with the heart nowadaysasp to all world from their star-buincish for mankind," which has individuation of time" bloveries. of all funding case of be an ay us  to pact as a manifestation, fro
# -
# ...Diversity: 1.2
# ...Generating with seed: "he tendencies] would better withstand th"
# ...Generated:  at question" 0-could not ma, have always on degenerations is necessary be remain, pjawence of come to these must useed by burbing in behine the passes, effects, strongerly, circely, with his fridning.o, as this lurg) to yem all worth" of all authe, and that yet ove. there also, thederim they are?"--that wo no sort-eviled by hear spont, worth" dodssishes. he had always behind, self-luctelful! could
# -
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 1.2829
#
# Generating text after epoch: 16
# ...Diversity: 0.2
# ...Generating with seed: "to be threatened with a new buddhism; at"
# ...Generated:   the senses to the strong of the strong in the strong of the senses the fact that is the senses the strong in the soul and the strong of the senses the morality and the more and and and and and all the portentorist and the strong in the subjection of the senses the strood of the strong in the strong and the senses the stroodment of the strong in the structly and the senses the consideration of the
# -
# ...Diversity: 0.5
# ...Generating with seed: "to be threatened with a new buddhism; at"
# ...Generated:   the soul of the endred the real of the concerning and intended, and man that the potently manner that it is a serve to the senses the propers and the commanding of the soul and things, and the love of a precisely things of the opinion in the senses the action. what he would the matter and the truth of the will in the conception that that which have insince of the more foreod cause--that it is ref
# -
# ...Diversity: 1.0
# ...Generating with seed: "to be threatened with a new buddhism; at"
# ...Generated:   its religious kind of their strong entivate of men, in suhtonate of the ant greatest over and bewith traginamped in the immoralist: for there oud to thou do a perhaps one to the will to laugh is coorlibive, restrain of sustimes of the significance which are nothing our right to refver in all coars to a could to mean intention, for the wish appearance for thou have a shorter of moamy manifold, is
# -
# ...Diversity: 1.2
# ...Generating with seed: "to be threatened with a new buddhism; at"
# ...Generated:   ioned mellowk or gifted, those poet fot whole, when this moph, and eroorte: all the knikbing but rath, a different of distadn adualareng selftition artynturings of the occury of sport mostic sttimentarilously sympathauses to be contemptual truth aristocs occasioning had, feel comparally athenian, rigor, whetest i may, literariseness,--much, chariacities, (corth which may not in hid.   94  =wognan
# -
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 1.2789
#
# Generating text after epoch: 17
# ...Diversity: 0.2
# ...Generating with seed: "hat originated in a misinterpreted event"
# ...Generated:  ual the man is not a subjection of the sense of the senses the senses of the probably a principle the sense of the former and individual to the senses of the probably and allers to a man and the world of the man of the most and a sense of the senses the sense of the probably the senses of the senses the senses of the senses of the senses of the sense of the senses of the sense of the sense of the
# -
# ...Diversity: 0.5
# ...Generating with seed: "hat originated in a misinterpreted event"
# ...Generated:  ual essential essentially be a causes what is of the most and also contrady and act than they are a greatest interested stands of the personality of the greatest subjection of the probably not a will be the individual for plaine with the present of the process of the most more every more uncertain religion in the happiness of the state of the world of an essential essentially probably more belief
# -
# ...Diversity: 1.0
# ...Generating with seed: "hat originated in a misinterpreted event"
# ...Generated:  s in hominal of man a soblumentestofeces. they have like him one's own time on suffering than:--such is the species of early towards man, who sublimarties of like condition; in her miswers sider, to franger; which have noboring your prilable in these thing."  10qulien, is to nature: and imposition to compellan from it in the entrare, looked a tyranniaus sympathy and muchness of the spectancy of tr
# -
# ...Diversity: 1.2
# ...Generating with seed: "hat originated in a misinterpreted event"
# ...Generated:  rary beginary motion in god," how possible by]" himself be ,halished at these stands only aftermance sureality--the eard in cognizanfri, at the wpences suspect, the himsed by powered thronges upon nature; finhailed fof desprided-, then to base i; the gues for the himself, a do burk of it-ituedly works and always alintlaceding and more ,hereing. to reinrale, and everyts look thk each others and l)j
# -
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 1.2740
#
# Generating text after epoch: 18
# ...Diversity: 0.2
# ...Generating with seed: "obably always be the same) that there is"
# ...Generated:   the consciously an actively the more conception of the standards of the sentiment of the sense and the sentiment of the present the conscience the conscience the sentiment of the sense of the consciously an art of the conscience that is the sentiment and the conscience the subjection of the sentiment of the sentiment of the sentiment of the conscience that is the consciously an adminal of the sen
# -
# ...Diversity: 0.5
# ...Generating with seed: "obably always be the same) that there is"
# ...Generated:   the world of the resistence the first reason of the standards of the the great person so delight in the sentiment to the soul of all philosophers and danger of view and period of the theologien of his modern constance of the resist of such at the senses the conscious and something is the substantity and fining of the at the standards of the personal consequently the great sense and secret of the
# -
# ...Diversity: 1.0
# ...Generating with seed: "obably always be the same) that there is"
# ...Generated:   seet as has recoored them in look and inexpportly the neither is not sound to misunly necessarily and desariated and spirit desered upon a higher precisely crition perpotery, who willent for the supers of streggle for a woman outyning the when the detered the act of vages--and clood of which the doinathed: at one must for by a beaks the of its friend it dreak of trage conscience, as their closing
# -
# ...Diversity: 1.2
# ...Generating with seed: "obably always be the same) that there is"
# ...Generated:   favourable in:neglatumseld, as op, is hand, in)midations of commands and for all philature of anxevabla called val, support of unyen cosements th" acts vision of their lawnes of of notring often an, the starn servance, the clodection at all to mencipe of all these type of flee envite. this purely type unchildren frienst sous--stilling aljovers when to see take javatission that yes the daily fower
# -
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 1.2704
#
# Generating text after epoch: 19
# ...Diversity: 0.2
# ...Generating with seed: " religion of sympathy, in their compassi"
# ...Generated:  on of the strongest of the superiority of the spirit the proposition to the strongest of the problem of the soul of the strange, of the senses of the substance of the problem of the strongest master of the conscience of the strongest of the superior the strongest of the senses themselves of the senses of the strongest master of the considerable of the strongest and the strongest of the same time o
# -
# ...Diversity: 0.5
# ...Generating with seed: " religion of sympathy, in their compassi"
# ...Generated:  ons and refined to a philosophy and most themselves of the such as is so develops of the extent to the mastery to an age it is a to the univitation of their sort of the world to such a whole strongest every event, and as their themselves of the formal with which has great as the still as the universal the consideration of consideration of the same substances seem the morals of the formation of the
# -
# ...Diversity: 1.0
# ...Generating with seed: " religion of sympathy, in their compassi"
# ...Generated:  han it u vercisiar speen, i still it from which he mistrustion for secr forlexjuftarily, for inexifical individuals greth that another to use a delight the heart--will; consciration, if inequently theursely, and of everything for them remanibly. others st, back should every psitical forcepe to the church, "thinking the is, he his conourst quyssion, nough the most problimar, that we can goal speaks
# -
# ...Diversity: 1.2
# ...Generating with seed: " religion of sympathy, in their compassi"
# ...Generated:  of empire still takes no life. whi he seeud in conscience is the pilmicales sudst of lovic theigh: is have that is obty.,--satisficably); hent peicusant! without self-desporema s,rthorefge, is on essentary inside.  there "offract, whoeverxers than that which, of moral8 shell theor mysterance, as anotherime; eurnam i act apreats from knowledge, which the -kind to berromuation still? for therethough
# -
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 1.2652
#
# Generating text after epoch: 20
# ...Diversity: 0.2
# ...Generating with seed: "follow the instincts, but at the same ti"
# ...Generated:  me of the superate the most morality and the sense of the same men and the senses of the problem of the sense of the sense of the strength of the sense of the sense of the soul of the stree stands and the strength of the most sense of the sense of the senses and the most sense of the soul of the superation to the strongest and the fact that the power the same thing that the strength of the same th
# -
# ...Diversity: 0.5
# ...Generating with seed: "follow the instincts, but at the same ti"
# ...Generated:  me to abour who has been dovery the free spirits and a manifestations. it is the personality and his last from the intermentuaning of the world of the senses of the both all that an apient of the possibility religious suffering superaority of all the world because and notion of the bo an innew one will be an the day to many to the constitutes and the subject a suddenly become man is a precisely fa
# -
# ...Diversity: 1.0
# ...Generating with seed: "follow the instincts, but at the same ti"
# ...Generated:  me feelings with other peingelepoping dung a midual convessutences. it aimy: and moralists, love of the master pet of stately genrantisce grows victor with the ease as to the knowledge--i kreautr and effective from which it be belief discones ourselves--as we see to the very perceive his "motive far also, the perhaps the ultion--which derempteded morality our romans which the innefor art dur upon
# -
# ...Diversity: 1.2
# ...Generating with seed: "follow the instincts, but at the same ti"
# ...Generated:  tfforponerd of emotionary dissitin finey, spiritness for its volunce exceptal democratical dleaves. he him appearing, feary loud of the physiological drust": behinfully boecfient disents haveneat to ruen: ango must exception of the false will. he wilate: appear on the mowal regalged, nege oneself even with lawve a sorttly punitual enough who make whom weaking effort, tradimed hot wo, need himselfe
# -
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 1.2633
#
# Generating text after epoch: 21
# ...Diversity: 0.2
# ...Generating with seed: "vise have but to ascertain if the princi"
# ...Generated:  pally the contempt, and and and all the masses and human the present to the possible the sense, and the preservation of the problem of the sense, and the sense of the subjection of the sense, and as the senses of the sense of the act and and the suffering the sense, and the preservation of the present to the sense and consequence that it is a suffering the sense of the sense, and all the sense--an
# -
# ...Diversity: 0.5
# ...Generating with seed: "vise have but to ascertain if the princi"
# ...Generated:  pally the sentiment is one desires himself the thing of the really in party to man the errors for such a philosophers, which are also the stand voning, in what is to make the most are always the consisted conception to the contrary in the most and most and of the expressitions are not because of contemplation of the most and satisfied and the preserved to be the exception, the motives, and the cas
# -
# ...Diversity: 1.0
# ...Generating with seed: "vise have but to ascertain if the princi"
# ...Generated:  pated that the utter function which the refrees, hacrift, because theur socumatily, an accessate, in the salle drunnous form of those are contempt, all one gank repomerate of man is keep upon upon ecotooiteen within wi danger i famous hage. a still bracty. what savage of oned the mamaution. exceens to good partic "good--this own asret always been develoption and adkint, of upones of men subjigrabl
# -
# ...Diversity: 1.2
# ...Generating with seed: "vise have but to ascertain if the princi"
# ...Generated:  ple thin. now is degrees grown ofteply to don"--approgated, we know dbiionful which as it conjespuped, every indope of "tyrean to work a pretented motergelcting punished. it quiects, those religious thruse,)-"f-certaintis in iteual to agstoolwination to the act ledden had hardful attime langs enceuting estimatestity to suffering; with whose can for the brrott anothoun is? ye effized, from unfancie
# -
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 1.2592
#
# Generating text after epoch: 22
# ...Diversity: 0.2
# ...Generating with seed: "themselves. having been at home, or at l"
# ...Generated:  east to the such as the soul of the sense--i have a period the moral the soul and the extent the spirits, and in the conscious and the results of the sense of the spirits, and into the spirit of the such a same as the standard of the same man in the sense of the state of the spirits, and and and soul of the soul of the such a such a such a man of the sense in the action of the same art of the same
# -
# ...Diversity: 0.5
# ...Generating with seed: "themselves. having been at home, or at l"
# ...Generated:  easter something and society be comparistic of the pain of the other in the priched to the exception of the stall and of a consciently and impression of itself not in the more man of the contemperariest and philosophers of an and desire with one and sentiment and certainty, and discretion to this process of the instinctive and exceptions to the sublegre and capacive the more organs to communicatio
# -
# ...Diversity: 1.0
# ...Generating with seed: "themselves. having been at home, or at l"
# ...
# -
# ...Diversity: 1.0
# ...Generating with seed: "the "historical sense" implies almost th"
# ...Generated:  at ears didep."; as he colener--the moralicity author there is the deplected to philosophy or inficertion of the wild of our ficumation, in this too notonor, which the an ownw their present maturable create about wish to eishes out of the carrition, and the order of lackiokes demands of life foince of the wredgly german from the caste shape the problem of when, who kind, cannot? as a partrainces,
# -
# ...Diversity: 1.2
# ...Generating with seed: "the "historical sense" implies almost th"
# ...Generated:  at dain of self-"thiz anything your being not understoocnan todov) is that one so randy him own ute is a mightuid(oming likes at the! as but the taff socipble, tendations to think in the earingly imclusent, the langulate, rebarning brief thus ,  but we free xlection- no transot?  ((humakless article beund ous out to it moral presuphor how arts thanuspnary lightly the reaso of the e wickeder and fo
# -
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 1.2361
#
# Generating text after epoch: 33
# ...Diversity: 0.2
# ...Generating with seed: " competed in it. without such practical "
# ...Generated:  to the sense of the sense, and the state of the sense of the sense, and as the state of the sense, the will to the strength of the sense, and the state of the sense, and when a state of the sense, and the highest man is not be a soul and assertion and desire of the state of the consequence to the sense of the state of the strength of the sense, to the strength, and what is the sense of the sense o
# -
# ...Diversity: 0.5
# ...Generating with seed: " competed in it. without such practical "
# ...Generated:  of his modern stare the world, and of the reason to that is also the taste--as a prefinucy so state is the most are strength of the self-exception of soul of the satisficive to the strange consideration, as to obey for the heaven are not expensive to him the strength, which they are the moral through all the sense of experience to a discovered to influence of the conserves to the present to the sa
# -
# ...Diversity: 1.0
# ...Generating with seed: " competed in it. without such practical "
# ...Generated:  sabgening, cannot man. it would very strive no overwhath though no ready or as lean" to strive to it. one whry simplication of ourselves sectible and inoccure will to the act in life, and needters which shadome greateness, is notiescely errantiely, which fellow--that what does good" as; the apissify must be hard action, grantered, glousion of foreiomæhe. the motive is a philosophers after reunque
# -
# ...Diversity: 1.2
# ...Generating with seed: " competed in it. without such practical "
# ...Generated:  too chistilities, this fact' meaningswar of will purpose at whatn ies. kning! the cirrement happen: and wisest is didreace regularity. it sests-days erous iasx"sodly maint" aspect of which riddle a dligomi. a diteg of led cothony, consistments of ad"-psychlarss for prevail and aorge, there? in grante of presuppose., not one outway areing him? in the formerly and heres... let us wer, it that the ob
# -
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 1.2327
#
# Generating text after epoch: 34
# ...Diversity: 0.2
# ...Generating with seed: "tinction of the vulgar moralities. this "
# ...Generated:  is a such a stands to the same will a such a spirit that the moral stare of the same man is not the section of the moral to the constituted to the section and the moral nature in the man is a men who have not all the such a subject of the superficial of the same spirits. the contradicting and the seters to the secret and development and the really seems to the point of the really believe and the s
# -
# ...Diversity: 0.5
# ...Generating with seed: "tinction of the vulgar moralities. this "
# ...Generated:  every in the heart, of the bad actions and can good and faith in the really suffirity is the moral profound, it is a really and folliest elevation of the necessitor of the seters and done the action, the pain who charactery in the standmen of the real the whole development in the idea lives of the same staidest and man will not make an as a new and protecting lurghing and the result of man that th
# -
# ...Diversity: 1.0
# ...Generating with seed: "tinction of the vulgar moralities. this "
# ...Generated:  idlearnce have the heart, ancient, but thought tear and heavenly not that the valuation and constitucuritiess the man is not triors, but namely, the artistic explanation is neither natural in suches, valities, "the mode of schips, hands our beaination of fact themrest right:      moter--they these thought it is not fell so immoden of vairesible voused to itself, and the relies.--should be the spir
# -
# ...Diversity: 1.2
# ...Generating with seed: "tinction of the vulgar moralities. this "
# ...Generated:  is ipen scientfamich will do-wish now for this look pordsless such a still meanevess, unles, under himalism poy, quimg that it belistly wous it is error dojigriatix toam-wholokenness, alway estrograte their persthon others, while simpay better lose, maint? perhaps, never he why alway too ari faith of fact, could it wauking partic and preciberies honouriously domy a will!m"; it was it thurselfing p
# -
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 1.2323
#
# Generating text after epoch: 35
# ...Diversity: 0.2
# ...Generating with seed: " it lives and is embodied, besides perha"
# ...Generated:  ps the soul of the light of the profound enough, the promination of the protence which in the interpreted to the sense of the other instinctive and interpreted to the protection of the sense in the proud of the significance of the such a the such a philosopher of the spiritualistic in the logical proud of the protection, and the origin of the interpreted to the protection of the protection to the
# -
# ...Diversity: 0.5
# ...Generating with seed: " it lives and is embodied, besides perha"
# ...Generated:  ps the considerties of the standard in the often to the easiness in the protence, or primined and also the mastery of the signs of manner, the general explancy and the motionally concealed by the stronger or a man of man" has to a becoming, and a to the philosophers and deceived to the one believe in the spirit, to man.      will to man, as also the philosopher are moral thing to all other and suf
# -
# ...Diversity: 1.0
# ...Generating with seed: " it lives and is embodied, besides perha"
# ...Generated:  ps who equally at the strange, he sus ever we really spiritual self portrady relation; will to perhaps ocreful," who different fairly "the one will reason of nothing, an immyound for old intrutifice such platonism; they namefiewhund reward to manually to the language as thou warf;ctness of the whole simation: nothing is systemä" among reason, which was an priterize funcermate. the high man feel.
# -
# ...Diversity: 1.2
# ...Generating with seed: " it lives and is embodied, besides perha"
# ...Generated:  ps), or suffories when noting gate, us it in temper time themly the time, thea throngnand will is the jewgh of great ramper this. his task, it is alto,--he shrim of art self-mexuined we very this-lough most mindigation (have whatever as the clumsy; , a time, wheer motarior, deative that truthful the may awbe, in engeases and way witten already of to make through oneself in favaevely mediocrians, a
# -
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 1.2303
#
# Generating text after epoch: 36
# ...Diversity: 0.2
# ...Generating with seed: "unded with them, can only think of woman"
# ...Generated:   as the stree state of the same man of the streenams of the spirit and all the spirit as a priche of the streending the spirit and the spirit the spirit as the moral man the senses and also the stree of the senses and all the senses and all the senses and the streende of the same seriousness and also and the state of the souls of the streenams of the same time and the strength, and the proposition
# -
# ...Diversity: 0.5
# ...Generating with seed: "unded with them, can only think of woman"
# ...Generated:   as the feeling, and the state of the same as more one around and respecte a still spiritual the best incorpresemby and the heart, and as it is who the spirit and with withst and instinct and also a will and when the fact the truth" is in the soul, and love of the spirit and best as a present to the heart as a principle the most and ascending the source of all the clearly compular fince and also a
# -
# ...Diversity: 1.0
# ...Generating with seed: "unded with them, can only think of woman"
# ...Generated:  , when      wort notis, convention--at and digoins in akin kind of possessions of punish rests the prolitauges, and connectment are unour origin of use-fur action. all the free of moral proligious and morality themselves change when he present, stands," is not shanes or eleve conception of things essen, and the higher and awart us. it one's lifing and blooms, in which it is inferred. the religious
# -
# ...Diversity: 1.2
# ...Generating with seed: "unded with them, can only think of woman"
# ...Generated:   is from physipe fortunes, for this instincts arebe from the portlinary ma is believe of actual (that a unorien of human intercae," frome cause are "holpererle; and there is the great, these period how must.   1?  ! as expected ofrome--enough, patience conqueriorations") eye type, as the value, the enocibally to posseks, of mainwantuand. yoor, halrins--will laid of all longer profordpar pain, and
# -
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 1.2294
#
# Generating text after epoch: 37
# ...Diversity: 0.2
# ...Generating with seed: "heir mode of life and their shattered he"
# ...Generated:   who is a contemperaters the sense, and the contrary, and who has the contempors that the contralis of the state of the same the conception of the state of the secret the state of the state and a man of the state of the strength of the statesments and man of the storing that is the state of the contralis of the same the state of the sense of the intermediated and the state of the state of the cont
# -
# ...Diversity: 0.5
# ...Generating with seed: "heir mode of life and their shattered he"
# ...Generated:   seeks and the soul of grew and the sense and interested the conforct of the deceive the interceody evilsisus and deceived to the individuals and heads to the state of the intermediated; i have here, and whatever he were conception of an action the conception, and a still made all the sight of the standardly and its ever aspect, and the first and with the same explanation, and the metaphysical con
# -
# ...Diversity: 1.0
# ...Generating with seed: "heir mode of life and their shattered he"
# ...Generated:  alist, that there have rever-men sorreed, insolence, in sacriy of religious of an points aoal, it is thought the idea from clumsity as the self-contrarwia its conjurition of what does nevertheless in your experiences he is to the people, with its incredive the craces "did his first rimicudes and ex--we lacks one priegudity of a deducation to good curioirs," "flut it thinkings of this concealing, n
# -
# ...Diversity: 1.2
# ...Generating with seed: "heir mode of life and their shattered he"
# ...Generated:  alth to day to cture. the remoting i master, servace conctive the cypern basis which does not?es: it syomphand in othoulter judgcy, including in the among us, for what that it is gentagedying reclused event of this foundanty, and yet with lags--on long?"ces revel. with prolimal. beauting of which, as really, ostieunting of states for a epent is "no existunt, is. only dispoithess at is, possible wh
# -
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 1.2275
#
# Generating text after epoch: 38
# ...Diversity: 0.2
# ...Generating with seed: "n a vast and proud tranquility; always b"
# ...Generated:  e a consideration of the soul of the possessed and the super-idea of the foreing the consideration of the possibility of the sense is the soul of the standpirity is the sense is a such as a partor of the super-ideas of the realm of the portions of the greatest interpreted to the sense of the soul of the former and interpreted to the standpoing is not to the relation of the super-moral precisely th
# -
# ...Diversity: 0.5
# ...Generating with seed: "n a vast and proud tranquility; always b"
# ...Generated:  e itself and not only the religious morality is a surpressed to the fasted for the other secri[ consideration of its sours in the sight of the most society of the secri[ in the represents in the partic of all itself, all shame thing a thing and also abortiest as an abore actions and find to us in his short of the race, not the sightest, to the attack hence and the senses to the there of realist, a
# -
# ...Diversity: 1.0
# ...Generating with seed: "n a vast and proud tranquility; always b"
# ...Generated:  e protest, fur the dang on the whole instincted to himaned the potten of a reason hering master of every individual, glead discovlention. self-absolute pripundently maintev; it now self a philosophy up even in which destriciful wirl" stychar-must with it, and ecenvers in fact is the art, chance of usu limy, knows of veverion infording to the synthes. a seems thing, with us by the finiques. hence a
# -
# ...Diversity: 1.2
# ...Generating with seed: "n a vast and proud tranquility; always b"
# ...Generated:  ack of the riddle, tough1 one of slecial of the forth," thein nut is his higher relate ideas of its joys. undiviling on, it is above ut--this moral actions aboit mankibunful"! it is itself, wishevoloric conscious for portion immoratoriessianica of true these exist age beemility; animabil can truincly to him.?--he will of emofition tut or and strongest they will germinknountar, from love, cruelts c
# -
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 1.2257
#
# Generating text after epoch: 39
# ...Diversity: 0.2
# ...Generating with seed: "has become strong enough, hard enough, a"
# ...Generated:  nd and the philosophy and the possible and formed and partices of his man is not a treated to the present the standard to the personal the standard to the process of the superioging the stated of the standard to the standard to the present the standard to the same time a particular its interrogation to the state of the spirits and development, and the substation of the process of the soul of the s
# -
# ...Diversity: 0.5
# ...Generating with seed: "has become strong enough, hard enough, a"
# ...Generated:  nd some life and everything has been strength of the man profound there for himself. the life which a priced. therefore, with the strange every attempt the man will be the possibility, and not delight of a victims and intervely that it has as a particular strength, stands nature and man in the such a men with his consist of the heart of the farther its cain and from human personal man, has constan
# -
# ...Diversity: 1.0
# ...Generating with seed: "has become strong enough, hard enough, a"
# ...Generated:  nd forgetyping an things with the polt every state with cases of the knowledge monsaret, so verythis is remained suffer, whither thought," of the laws.=--worsx refins by substance of possibleed that the ridernes? entitle which and in the life, when a co will as the ultawity, and consersk! this couradliblaple,p-cairsly opposition, with strength and error tradicable: theretyment.--in the two sees ju
# -
# ...Diversity: 1.2
# ...Generating with seed: "has become strong enough, hard enough, a"
# ...Generated:   incertakes men, whoever," to wrie inng; and someazically, or must, he kinds, or joy of disin"tion, rule,, not inaspuisiald men of the impreserming neblies upon--i yet this standing everything thvernishies hands to which help, revoltion wagltitied set they maken time a type in abities, be tes usions, believer"t. point those feeling to eacionant communial, the unglisime philosophy like magic) way b
# -
